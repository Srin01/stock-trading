# %%
from breeze_connect import BreezeConnect
import pandas as pd
import login as l
from dateutil.relativedelta import relativedelta, TH
from  datetime import datetime, date, time, timedelta
import time as ti
import warnings
warnings.filterwarnings("ignore")



breeze = BreezeConnect(api_key=l.api_key)
breeze.generate_session(api_secret=l.api_secret, session_token =l.session_key)
d = datetime.utcnow()
current_expiry_dt = l.current_expiry_dt


NSE_master = pd.read_csv('NSEScripMaster.csv')
NSE_master.columns = [i[2:-1] for i in NSE_master.columns]
nifty100 = pd.read_csv('ind_nifty100list.csv')
nifty100.rename(columns={'ISIN Code': 'ISINCode'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\OneDrive\Bulk Trading\Algo PDL\stock-trading\main_dev.ipynb Cell 1 in <cell line: 27>()
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a> sorted_codes.loc[~sorted_codes['ShortName'].isin(['ZOMLIM', 'ONE97'])]
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a> new ='code'
# ---> <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> sorted_codes.rename(columns={'ShortName', new},inplace=True)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5083, in DataFrame.rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4964 def rename(
#    4965     self,
#    4966     mapper: Renamer | None = None,
#    (...)
#    4974     errors: str = "ignore",
#    4975 ) -> DataFrame | None:
#    4976     """
#    4977     Alter axes labels.
#    4978
#    (...)
#    5081     4  3  6
#    5082     """
# -> 5083     return super()._rename(
#    5084         mapper=mapper,
#    5085         index=index,
#    5086         columns=columns,
#    5087         axis=axis,
#    5088         copy=copy,
#    5089         inplace=inplace,
#    5090         level=level,
#    5091         errors=errors,
#    5092     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1155, in NDFrame._rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1148         missing_labels = [
#    1149             label
#    1150             for index, label in enumerate(replacements)
#    1151             if indexer[index] == -1
#    1152         ]
#    1153         raise KeyError(f"{missing_labels} not found in axis")
# -> 1155 new_index = ax._transform_index(f, level=level)
#    1156 result._set_axis_nocheck(new_index, axis=axis_no, inplace=True)
#    1157 result._clear_item_cache()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6131, in Index._transform_index(self, func, level)
#    6129     return type(self).from_tuples(items, names=self.names)
#    6130 else:
# -> 6131     items = [func(x) for x in self]
#    6132     return Index(items, name=self.name, tupleize_cols=False)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6131, in <listcomp>(.0)
#    6129     return type(self).from_tuples(items, names=self.names)
#    6130 else:
# -> 6131     items = [func(x) for x in self]
#    6132     return Index(items, name=self.name, tupleize_cols=False)
#
# TypeError: 'set' object is not callable

# %%
sorted_codes = nifty100.merge(NSE_master, how='left', on='ISINCode')[['ShortName','CompanyName']]
sorted_codes.loc[~sorted_codes['ShortName'].isin(['ZOMLIM', 'ONE97'])]
sorted_codes.columns = ['code', 'company_name']

# %%
today = date.today()
yesterday = today - timedelta(days = 1)

if yesterday.weekday() ==6:
    yesterday=yesterday-timedelta(days=2)
    

if yesterday.weekday() ==5:
    yesterday=yesterday-timedelta(days=1)
    
for i in range(1,len(sorted_codes)):
    try:
        print("*******************************************************************************************************")
        code = str(sorted_codes.loc[i, "code"])
        stock_type = 'Cash' 
        print("for stock :", code)

        Stock_strike = breeze.get_historical_data(interval="1day",
                                    from_date= str(yesterday),
                                    to_date= str(yesterday),
                                    stock_code=code,
                                    exchange_code="NSE",
                                    product_type=stock_type,
                                    right="others",
                                    strike_price="0")

        df_stock = pd.DataFrame(Stock_strike['Success'])

        prev_day_stock_low = pd.to_numeric(df_stock['low'].iloc[0])
        prev_day_stock_low = float(prev_day_stock_low)  
        print("Prev Day Low :", prev_day_stock_low)

        today_stock = breeze.get_historical_data(interval="5minute",
                                    from_date= str(datetime.now()),
                                    to_date= str(datetime.now()),
                                    stock_code=code,
                                    exchange_code="NSE",
                                    product_type=stock_type,
                                    expiry_date=str(datetime.now()),
                                    right="others",
                                    strike_price="0")

            
        
        df_stock = pd.DataFrame(today_stock['Success'])
        df_new = df_stock[(pd.to_datetime(df_stock['datetime']).dt.time <= time(14,55)) & (pd.to_datetime(df_stock['datetime']).dt.time >= time(9,15))]
        
        df_new['datetime']= pd.to_datetime(df_new['datetime'])

        current_candle = df_new.iloc[-2]
        prev_candle = df_new.iloc[-3]
        
        print("Previous_candle Low :", prev_candle['low'])
        print("current_candle Close :", current_candle['close'])
        
        flag = 0
        target = float('inf')
        if flag == 0 and pd.to_numeric(current_candle['close']) <= prev_day_stock_low:
            flag = 1
        flag

        if flag == 1 and pd.to_numeric(current_candle['close']) >= prev_day_stock_low:
            flag = 2
            diff = abs(pd.to_numeric(current_candle['close']) - pd.to_numeric(prev_candle['low']))
        

        if flag == 2 and pd.to_numeric(current_candle['close']) >= float(target):
            buy_cash = breeze.place_order(stock_code=code,
                        exchange_code="NSE",
                        product=stock_type,
                        action="buy",
                        order_type="market",
                        stoploss="",
                        quantity="1",
                        validity="day")

            orderid = buy_cash['Success']['order_id']
            print(orderid)

            stop_loss = float(list(breeze.get_trade_detail(exchange_code=stock_type,order_id=orderid)['Success'])[0]['execution_price'])- diff
            target = pd.to_numeric(current_candle['close']) + 1.5 * diff 
            print("*******************************************************************************************************")
            check_time = datetime.utcnow().time()

    

        if check_time > time(14,55):

            today_date = datetime.today().replace(minute=0, hour=0, second=0, microsecond=0).isoformat()[:19]+ '.000Z'
            order_list = pd.DataFrame(breeze.get_order_list(exchange_code=stock_type,
                                from_date=today_date,
                                to_date=today_date)['Success'])

            portfolio = breeze.get_portfolio_positions()['Success']
            i = 0

            while portfolio != None and i < len(portfolio):
                breeze.square_off(exchange_code=stock_type,
                            product=stock_type,
                            stock_code=portfolio[i]['stock_code'],
                            # expiry_date=portfolio[i]['expiry_date'],
                            # right=portfolio[i]['right'],
                            # strike_price=portfolio[i]['strike_price'],
                            action="sell",
                            order_type="market",
                            validity="day",
                            # stoploss="0",
                            quantity="1",
                            # price="0",
                            # trade_password="",
                            disclosed_quantity="0")
                portfolio = breeze.get_portfolio_positions()['Success']
                i+=1

            #cancell all pending orders
            [breeze.cancel_order(exchange_code=stock_type,order_id=i) for i in list(order_list[order_list['order_type']=='StopLoss']['order_id'])]
    except:
        pass
# Out:
# *******************************************************************************************************
# for stock : ADAENT
# Prev Day Low : 3194.85
# Previous_candle Close : 3207
# current_candle Close : 3210.85
# *******************************************************************************************************
# for stock : ADAGRE
# Prev Day Low : 2000.0
# Previous_candle Close : 2118
# current_candle Close : 2120.5
# *******************************************************************************************************
# for stock : ADAPOR
# Prev Day Low : 778.25
# Previous_candle Close : 786.5
# current_candle Close : 786.65
# *******************************************************************************************************
# for stock : ADAGAS
# Prev Day Low : 3006.0
# Previous_candle Close : 3040
# current_candle Close : 3044.25
# *******************************************************************************************************
# for stock : ADATRA
# Prev Day Low : 3005.25
# Previous_candle Close : 3042.65
# current_candle Close : 3047.95
# *******************************************************************************************************
# for stock : AMBCE
# Prev Day Low : 497.5
# Previous_candle Close : 507.5
# current_candle Close : 505.2
# *******************************************************************************************************
# for stock : APOHOS
# Prev Day Low : 4264.05
# Previous_candle Close : 4275.6
# current_candle Close : 4284
# *******************************************************************************************************
# for stock : ASIPAI
# Prev Day Low : 3180.0
# Previous_candle Close : 3205
# current_candle Close : 3207.15
# *******************************************************************************************************
# for stock : AVESUP
# Prev Day Low : 4291.15
# Previous_candle Close : 4176.3
# current_candle Close : 4181.35
# *******************************************************************************************************
# for stock : AXIBAN
# Prev Day Low : 794.45
# Previous_candle Close : 809
# current_candle Close : 811.25
# *******************************************************************************************************
# for stock : BAAUTO
# Prev Day Low : 3552.15
# Previous_candle Close : 3612.35
# current_candle Close : 3618.5
# *******************************************************************************************************
# for stock : BAJFI
# Prev Day Low : 7221.0
# Previous_candle Close : 7339.15
# current_candle Close : 7348
# *******************************************************************************************************
# for stock : BAFINS
# Prev Day Low : 1685.1
# Previous_candle Close : 1706.55
# current_candle Close : 1714.05
# *******************************************************************************************************
# for stock : BAJHOL
# Prev Day Low : 6560.0
# Previous_candle Close : 6596.85
# current_candle Close : 6600.8
# *******************************************************************************************************
# for stock : BANBAN
# Prev Day Low : 264.6
# Previous_candle Close : 268.75
# current_candle Close : 268.8
# *******************************************************************************************************
# for stock : BANBAR
# Prev Day Low : 130.0
# Previous_candle Close : 135.05
# current_candle Close : 135.55
# *******************************************************************************************************
# for stock : BERPAI
# Prev Day Low : 611.0
# Previous_candle Close : 613
# current_candle Close : 612.95
# *******************************************************************************************************
# for stock : BHAELE
# Prev Day Low : 100.45
# Previous_candle Close : 102.25
# current_candle Close : 102.4
# *******************************************************************************************************
# for stock : BHAPET
# Prev Day Low : 297.1
# Previous_candle Close : 296.9
# current_candle Close : 296.9
# *******************************************************************************************************
# for stock : BHAAIR
# Prev Day Low : 763.05
# Previous_candle Close : 769.7
# current_candle Close : 770.3
# *******************************************************************************************************
# for stock : BIOCON
# Prev Day Low : 260.7
# Previous_candle Close : 264.75
# current_candle Close : 264.95
# *******************************************************************************************************
# for stock : BOSLIM
# Prev Day Low : 15436.95
# Previous_candle Close : 15619.15
# current_candle Close : 15630
# *******************************************************************************************************
# for stock : BRIIND
# Prev Day Low : 3769.25
# Previous_candle Close : 3775
# current_candle Close : 3776.45
# *******************************************************************************************************
# for stock : CHOINV
# Prev Day Low : 724.5
# Previous_candle Close : 729.5
# current_candle Close : 729.7
# *******************************************************************************************************
# for stock : CIPLA
# Prev Day Low : 1105.4
# Previous_candle Close : 1111.45
# current_candle Close : 1111.85
# *******************************************************************************************************
# for stock : COALIN
# Prev Day Low : 235.35
# Previous_candle Close : 237.6
# current_candle Close : 237.9
# *******************************************************************************************************
# for stock : COLPAL
# Prev Day Low : 1549.0
# Previous_candle Close : 1565.35
# current_candle Close : 1569
# *******************************************************************************************************
# for stock : DLFLIM
# Prev Day Low : 358.0
# Previous_candle Close : 358.45
# current_candle Close : 359.45
# *******************************************************************************************************
# for stock : DABIND
# Prev Day Low : 527.0
# Previous_candle Close : 532.45
# current_candle Close : 532.25
# *******************************************************************************************************
# for stock : DIVLAB
# Prev Day Low : 3541.05
# Previous_candle Close : 3587
# current_candle Close : 3588.55
# *******************************************************************************************************
# for stock : DRREDD
# Prev Day Low : 4263.05
# Previous_candle Close : 4350.3
# current_candle Close : 4360.5
# *******************************************************************************************************
# for stock : EICMOT
# Prev Day Low : 3469.8
# Previous_candle Close : 3510.65
# current_candle Close : 3514.45
# *******************************************************************************************************
# for stock : FSNECO
# Prev Day Low : 1198.0
# Previous_candle Close : 1181.05
# current_candle Close : 1183.8
# *******************************************************************************************************
# for stock : GAIL
# Prev Day Low : 85.05
# Previous_candle Close : 85.45
# current_candle Close : 85.5
# *******************************************************************************************************
# for stock : GLAPH
# Prev Day Low : 2143.75
# Previous_candle Close : 2161.35
# current_candle Close : 2160
# *******************************************************************************************************
# for stock : GODCON
# Prev Day Low : 830.95
# Previous_candle Close : 834.5
# current_candle Close : 835.3
# *******************************************************************************************************
# for stock : GRASIM
# Prev Day Low : 1687.8
# Previous_candle Close : 1695
# current_candle Close : 1694.45
# *******************************************************************************************************
# for stock : HCLTEC
# Prev Day Low : 994.0
# Previous_candle Close : 995.55
# current_candle Close : 995.9
# *******************************************************************************************************
# for stock : HDFAMC
# Prev Day Low : 1890.1
# Previous_candle Close : 1911.7
# current_candle Close : 1911.5
# *******************************************************************************************************
# for stock : HDFBAN
# Prev Day Low : 1415.25
# Previous_candle Close : 1443
# current_candle Close : 1444.55
# *******************************************************************************************************
# for stock : HDFSTA
# Prev Day Low : 521.8
# Previous_candle Close : 524.1
# current_candle Close : 524.3
# *******************************************************************************************************
# for stock : HAVIND
# Prev Day Low : 1238.15
# Previous_candle Close : 1228.75
# current_candle Close : 1227.15
# *******************************************************************************************************
# for stock : HERHON
# Prev Day Low : 2529.05
# Previous_candle Close : 2562.05
# current_candle Close : 2566.45
# *******************************************************************************************************
# for stock : HINDAL
# Prev Day Low : 396.4
# Previous_candle Close : 391.3
# current_candle Close : 392.85
# *******************************************************************************************************
# for stock : HINAER
# Prev Day Low : 2331.0
# Previous_candle Close : 2360.2
# current_candle Close : 2363.5
# *******************************************************************************************************
# for stock : HINLEV
# Prev Day Low : 2570.2
# Previous_candle Close : 2606.3
# current_candle Close : 2606.25
# *******************************************************************************************************
# for stock : HDFC
# Prev Day Low : 2305.0
# Previous_candle Close : 2347.9
# current_candle Close : 2352.05
# *******************************************************************************************************
# for stock : ICIBAN
# Prev Day Low : 868.55
# Previous_candle Close : 885.5
# current_candle Close : 886.85
# *******************************************************************************************************
# for stock : ICILOM
# Prev Day Low : 1123.05
# Previous_candle Close : 1134.5
# current_candle Close : 1135.1
# *******************************************************************************************************
# for stock : ICIPRU
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\OneDrive\Bulk Trading\Algo PDL\stock-trading\main_dev.ipynb Cell 3 in <cell line: 11>()
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> print("for stock :", code)
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> Stock_strike = breeze.get_historical_data(interval="1day",
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>                             from_date= str(yesterday),
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>                             to_date= str(yesterday),
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a>                             right="others",
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a>                             strike_price="0")
# ---> <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=25'>26</a> df_stock = pd.DataFrame(Stock_strike['Success'])
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a> prev_day_stock_low = pd.to_numeric(df_stock['low'].iloc[0])
#      <a href='vscode-notebook-cell:/d%3A/OneDrive/Bulk%20Trading/Algo%20PDL/stock-trading/main_dev.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a> prev_day_stock_low = float(prev_day_stock_low)
#
# KeyError: 'Success'
